# %% [markdown]
# # **Introduction to Pandas** 🐼

# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %%
import pandas as pd

# %%
print(pd.__version__)     # Checking Pandas version
# Out:
# 1.3.5

# %% [markdown]
# ## **Creating Pandas DataFrame** 🏬

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# ## **What is a Series?**
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
print(myvar[1])   # Getting data with labels
# Out:
# 7

# %%
a = [1, 7, 2, 8]

myvar = pd.Series(a, index = ["x", "y", "z", "a"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# a    8
# dtype: int64

# %%
myvar['z'] # Getting data with index labels
# Out:
# 2

# %%
# Getting data with index labels by Dictionary 

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
myvar['day1']
# Out:
# 420

# %% [markdown]
# ## **DataFrames**
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/Iris.csv") # getting Data from Url
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## **ILOC vs LOC function in Pandas**

# %%
data.loc[3]       # Using Loc function
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
data.iloc[3]       # Using iLoc function
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
data.head(10)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %%
data.drop(3,axis=0,inplace=True)    # Dropping Data row at Index 3

# %%
data.loc[3]       # Using Loc function too get index 3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data.iloc[3]       # Using Loc function too get index 3
# Out:
# Id                         5
# SepalLengthCm            5.0
# SepalWidthCm             3.6
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 4, dtype: object

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/Iris.csv") # getting Data from Url

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## **Understanding the Data**
#
# **Reading the data to Pandas**
#
# Explore this link in order to get full insights
#
# Pandas on reading data - > [Explore Pandas](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#
#
# Any valid string path is acceptable. The string could be a URL. Valid URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is expected. A local file could be: file://localhost/path/to/table.csv.
#
# If you want to pass in a path object, pandas accepts any os.PathLike.
#
# By file-like object, we refer to objects with a read() method, such as a file handle (e.g. via builtin open function) or StringIO.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/Iris.csv")

# %% [markdown]
# ### Renaming the Columns

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Renaming the Columns

df.rename(columns={'Species':'Flower Species'},inplace = True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Flower Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.rename(columns={'SepalLengthCm':'SepalLength','SepalWidthCm':'SepalWidth'},inplace = True)

# %%
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLengthCm  PetalWidthCm  Flower Species
# 0      1          5.1         3.5            1.4           0.2     Iris-setosa
# 1      2          4.9         3.0            1.4           0.2     Iris-setosa
# 2      3          4.7         3.2            1.3           0.2     Iris-setosa
# 3      4          4.6         3.1            1.5           0.2     Iris-setosa
# 4      5          5.0         3.6            1.4           0.2     Iris-setosa
# ..   ...          ...         ...            ...           ...             ...
# 145  146          6.7         3.0            5.2           2.3  Iris-virginica
# 146  147          6.3         2.5            5.0           1.9  Iris-virginica
# 147  148          6.5         3.0            5.2           2.0  Iris-virginica
# 148  149          6.2         3.4            5.4           2.3  Iris-virginica
# 149  150          5.9         3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns = ['Id',	'SepalLength',	'SepalWidth',	'PetalLength',	'PetalWidth',	'Flower Species']
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth  Flower Species
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              150 non-null    int64
#  1   SepalLength     150 non-null    float64
#  2   SepalWidth      150 non-null    float64
#  3   PetalLength     150 non-null    float64
#  4   PetalWidth      150 non-null    float64
#  5   Flower Species  150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Id', 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth',
#        'Flower Species'],
#       dtype='object')

# %%
df['SepalWidth']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidth, Length: 150, dtype: float64

# %%
d = df.PetalWidth
print(type(d))
d.plot()
# Out:
# <class 'pandas.core.series.Series'>

# %%
d = df.SepalWidth
d.plot()

# %% [markdown]
# # **Essential Pandas Functions and Practices** ⭕

# %%
df.describe()
# Out:
#                Id  SepalLength  SepalWidth  PetalLength  PetalWidth
# count  150.000000   150.000000  150.000000   150.000000  150.000000
# mean    75.500000     5.843333    3.054000     3.758667    1.198667
# std     43.445368     0.828066    0.433594     1.764420    0.763161
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     38.250000     5.100000    2.800000     1.600000    0.300000
# 50%     75.500000     5.800000    3.000000     4.350000    1.300000
# 75%    112.750000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
df.SepalLength.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: SepalLength, dtype: float64

# %%
df['Flower Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Flower Species, dtype: int64

# %%
df['Flower Species'] == 'Iris-virginica'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Flower Species, Length: 150, dtype: bool

# %%
df[df['Flower Species'] == 'Iris-virginica']
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth  Flower Species
# 100  101          6.3         3.3          6.0         2.5  Iris-virginica
# 101  102          5.8         2.7          5.1         1.9  Iris-virginica
# 102  103          7.1         3.0          5.9         2.1  Iris-virginica
# 103  104          6.3         2.9          5.6         1.8  Iris-virginica
# 104  105          6.5         3.0          5.8         2.2  Iris-virginica
# 105  106          7.6         3.0          6.6         2.1  Iris-virginica
# 106  107          4.9         2.5          4.5         1.7  Iris-virginica
# 107  108          7.3         2.9          6.3         1.8  Iris-virginica
# 108  109          6.7         2.5          5.8         1.8  Iris-virginica
# 109  110          7.2         3.6          6.1         2.5  Iris-virginica
# 110  111          6.5         3.2          5.1         2.0  Iris-virginica
# ...

# %%
fp = df[df['Flower Species'] == 'Iris-virginica']

# %%
fp.reset_index(drop=True)
# Out:
#      Id  SepalLength  SepalWidth  PetalLength  PetalWidth  Flower Species
# 0   101          6.3         3.3          6.0         2.5  Iris-virginica
# 1   102          5.8         2.7          5.1         1.9  Iris-virginica
# 2   103          7.1         3.0          5.9         2.1  Iris-virginica
# 3   104          6.3         2.9          5.6         1.8  Iris-virginica
# 4   105          6.5         3.0          5.8         2.2  Iris-virginica
# 5   106          7.6         3.0          6.6         2.1  Iris-virginica
# 6   107          4.9         2.5          4.5         1.7  Iris-virginica
# 7   108          7.3         2.9          6.3         1.8  Iris-virginica
# 8   109          6.7         2.5          5.8         1.8  Iris-virginica
# 9   110          7.2         3.6          6.1         2.5  Iris-virginica
# 10  111          6.5         3.2          5.1         2.0  Iris-virginica
# 11  112          6.4         2.7          5.3         1.9  Iris-virginica
# ...

# %% [markdown]
# # **Getting Used to Pandas** ⚡

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/project_data.csv") # Getting the Data

# %%
#first 5 rows
df.head(30)
# Out:
#     customer_id  year_of_birth  educational_level marital_status  \
# 0      20201701            1982        Graduation         Single
# 1      20201702            1950        Graduation        Married
# 2      20201703            1965        Graduation       Divorced
# 3      20201704            1984        Graduation   Relationship
# 4      20201705            1981               PhD        Widowed
# 5      20201706            1967            Master   Relationship
# 6      20201707            1971        Graduation       Divorced
# 7      20201708            1985               PhD        Married
# 8      20201709            1974               PhD        Widowed
# 9      20201710            1950               PhD         Single
# 10     20201711            1983        Graduation         Single
# 11     20201712            1976             Basic   Relationship
# 12     20201713            1959        Graduation       Divorced
# ...

# %%
df.tail()
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 494        55614.0    11/27/2013       85                 9                6
# 495        59432.0     4/13/2013       88                 5               11
# 496        55563.0      4/5/2014       22                 2                3
# 497        43624.0     4/21/2013       83                 4                4
# 498        41461.0     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms
# 494           0      3         11
# 495           0      3         11
# ...

# %%
#check the basic information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        499 non-null    int64
#  1   year_of_birth      499 non-null    int64
#  2   educational_level  499 non-null    object
#  3   marital_status     499 non-null    object
#  4   annual_income      486 non-null    float64
#  5   purhcase_date      499 non-null    object
#  6   recency            499 non-null    int64
#  7   online_purchases   499 non-null    int64
#  8   store_purchases    499 non-null    int64
#  9   complaints         499 non-null    int64
#  10  calls              499 non-null    int64
#  11  intercoms          499 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 46.9+ KB

# %%
#extract the shape of the data
df.shape
# Out:
# (499, 12)

# %%
df.describe()
# Out:
#         customer_id  year_of_birth   annual_income     recency  \
# count  4.990000e+02      499.000000     486.000000  499.000000
# mean   2.020195e+07     1978.284569   51454.504115   48.228457
# std    1.441932e+02       14.471242   21619.285903   29.077101
# min    2.020170e+07     1899.000000    2447.000000    0.000000
# 25%    2.020183e+07     1970.000000   33858.000000   23.000000
# 50%    2.020195e+07     1981.000000   50841.500000   47.000000
# 75%    2.020207e+07     1989.000000   68483.750000   74.000000
# max    2.020220e+07     2000.000000  157243.000000   99.000000
#
#        online_purchases  store_purchases  complaints       calls   intercoms
# count        499.000000       499.000000  499.000000  499.000000  499.000000
# mean           3.969940         5.779559    0.252505    3.370741   10.168337
# std            2.813675         3.301378    1.115953    4.327091    2.800552
# min            0.000000         0.000000    0.000000    0.000000    2.000000
# ...

# %%
df['marital_status'].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed'],
#       dtype=object)

# %%
df['marital_status'] = df['marital_status'].replace('Widow', 'Widowed')

# %%
df['educational_level'].value_counts()
# Out:
# Graduation     257
# PhD            114
# Master          81
# High School     40
# Basic            7
# Name: educational_level, dtype: int64

# %%
subset_data = df[['year_of_birth ', 'educational_level', 'annual_income']]
subset_data
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 494            1944               PhD        55614.0
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
#
# [499 rows x 3 columns]

# %%
df[df["educational_level"] == "Master"]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 5       20201706            1967            Master   Relationship
# 13      20201714            1952            Master         Single
# 18      20201719            1980            Master         Single
# 30      20201731            1989            Master       Divorced
# 31      20201732            1963            Master         Single
# ..           ...             ...               ...            ...
# 481     20202182            1972            Master       Divorced
# 484     20202185            1960            Master   Relationship
# 486     20202187            1976            Master   Relationship
# 493     20202194            1964            Master         Single
# 495     20202196            1962            Master       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 5          62000.0      9/9/2013       16                 6               10
# ...

# %%
df.loc[:6, ['educational_level', 'recency']] #specify the rows and columns as labels
# Out:
#   educational_level  recency
# 0        Graduation       58
# 1        Graduation       38
# 2        Graduation       26
# 3        Graduation       26
# 4               PhD       94
# 5            Master       16
# 6        Graduation       34

# %%
df.iloc[:6, [2,6]] #speciy rows and columns as integer based values
# Out:
#   educational_level  recency
# 0        Graduation       58
# 1        Graduation       38
# 2        Graduation       26
# 3        Graduation       26
# 4               PhD       94
# 5            Master       16

# %%
df.loc[df['marital_status'].isin(['Single', 'Divorced'])]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 2       20201703            1965        Graduation       Divorced
# 6       20201707            1971        Graduation       Divorced
# 9       20201710            1950               PhD         Single
# 10      20201711            1983        Graduation         Single
# ..           ...             ...               ...            ...
# 491     20202192            1976        Graduation       Divorced
# 493     20202194            1964            Master         Single
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
df.annual_income.isnull().value_counts()
# Out:
# False    486
# True      13
# Name: annual_income, dtype: int64

# %%
for i in df.columns:
  print(f"Total Null in {i} :\t\t {sum(df[i].isnull())}")
# Out:
# Total Null in customer_id :		 0
# Total Null in year_of_birth  :		 0
# Total Null in educational_level :		 0
# Total Null in marital_status :		 0
# Total Null in annual_income :		 13
# Total Null in purhcase_date :		 0
# Total Null in recency :		 0
# Total Null in online_purchases :		 0
# Total Null in store_purchases :		 0
# Total Null in complaints :		 0
# Total Null in calls :		 0
# Total Null in intercoms :		 0

# %%
df.iloc[list((df.annual_income > 75000) & (df.educational_level == 'Master'))]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %% [markdown]
# # **Hands On Data** 🤚

# %% [markdown]
# 1. **Find and print count of each kind of flower (separated by space)?**
# ```
# count1 count2 count3 .....
# ```

# %%
# data link "https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/iris2.csv"


# code Here

# %% [markdown]
# 2. **Find the data of flower “Iris-virginica” type where petal-length > 1.5?**
# ```
# feature1 feature2 feature3 feature4 feature5
# feature1 feature2 feature3 feature4 feature5
# feature1 feature2 feature3 feature4 feature5
# feature1 feature2 feature3 feature4 feature5
# ```

# %%
# data link "https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/iris2.csv"

# code Here

# %% [markdown]
# 3. **Find and print the minimum, maximum and average value of the feature for
# each kind of flower ?**
# ```
# minSL minSW minPL minPW Iris-setosa
# maxSL maxSW maxPL maxPW Iris-setosa
# avgSL avgSW avgPL avgPW Iris-setosa
# .
# .
# .
# .
#
# ```

# %%
# Data Link https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# HINT : you have to define column names 

# code Here
# Out:
# 4.30 2.30 1.00 0.10 Iris-setosa
# 5.80 4.40 1.90 0.60 Iris-setosa
# 5.01 3.42 1.46 0.24 Iris-setosa
# 4.90 2.00 3.00 1.00 Iris-versicolor
# 7.00 3.40 5.10 1.80 Iris-versicolor
# 5.94 2.77 4.26 1.33 Iris-versicolor
# 4.90 2.20 4.50 1.40 Iris-virginica
# 7.90 3.80 6.90 2.50 Iris-virginica
# 6.59 2.97 5.55 2.03 Iris-virginica

# %% [markdown]
# ## New Data File

# %% [markdown]
# Given file "terrorismData.csv"
#
# It is an open-source database including information on terrorist attacks around the world from 1970 through 2017. This dataset includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period

# %% [markdown]
# [Download the Data from Here](https://drive.google.com/file/d/1cZVEZPRMj4YuxnomzbDyVlC-2pR7yC5H/view?usp=sharing)

# %% [markdown]
# 4. **Problem Statement :**
#
# The Most Dangerous city in Jammu and Kashmir and the terrorist group which is most active in that city?
# Print count of number of attacks in that city as integer value.
# Note:Ignoring the Unknown Terrorist Group.Here Dangerous related with the number of terrorist attacks.
# ```
# Output Format :
# City NumberOfAttack Group
# ```

# %%
path='/content/drive/MyDrive/Data/terrorismData.csv'

# %%
# code Here
# Srinagar 657 Muslim Separatists

# %% [markdown]
# 5. **Problem Statement :**
#
# There was formation of new government in India on 26 May 2014. So current government's span is from 26th May 2014 to current. Find out two things from this period-
#
# 1. Total number of attacks done in this period in India. Find this count as integer.
#
# 2. Which Terrorist group was most active in this period in India. Most active means, group which has done maximum number of attacks.
#
# 3. Ignore the Unknown group.
# ```
# Output Format :
# TotalAttacks MostActiveTerroristGroup
# ```

# %%
# code Here
# 3336   Maoists

# %% [markdown]
# 6. **Problem Statement :**
#
# Find the frequency of the Casualty in Red Corridor states and in Jammu and Kashmir ?Here Frequency is (Total Casualty/Total Number of a year)
# Print frequency as integer value.
#
# >Note:Red Corridor state includes Jharkhand, Odisha, Andhra Pradesh, and Chhattisgarh. Here Casualty=Killed +Wounded.Don't fill the nan value present in Killed and Wounded feature.
#
#
#
#
# ```
# Output Format :
# Frequency1 Frequency2
# ```

# %%
# code Here
# 115   261

# %% [markdown]
# 7. **Problem Statement :**
#
# Most Deadliest attack in a history of HumanKind?
# Print count of Killed people as integer value.
#
# >Note: Here Deadliest attack means, in which the most number of people killed.
#
# ```
# Output Format :
# NumberOfPeopleKilled Country TerroristGroup
# ```

# %%
# code Here
# 1570   Iraq   Islamic State of Iraq and the Levant (ISIL)

# %% [markdown]
# 8. **Problem Statement :**
#
# Find out the Country with Highest Number of Terror Attack and in which year the most number of terrorist attack happened in that country ?
# Print count of terror attacks as integer value.
#
# ```
# Output Format :
# Country NumberOfAttack Year
# ```

# %%
# code Here
# Iraq   24636   2014
