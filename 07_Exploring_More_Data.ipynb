# %%
file= "https://raw.githubusercontent.com/Ambatkar/Test_mnist/main/data/Amazon_jobs_dataset%20-%20amazon_jobs_dataset.csv"

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    S.No.                                       Title            location  \
# 0      0                Software Development Manager    US, WA, Seattle
# 1      1               Software Development Engineer  IN, KA, Bangalore
# 2      2               Software Development Engineer  IN, KA, Bangalore
# 3      3  Software Development Engineer - Amazon Lex    US, WA, Seattle
# 4      4  Software Development Engineer - Amazon Lex    US, WA, Seattle
#
#     Posting_date                                        DESCRIPTION  \
# 0  March 1, 2018  You are an experienced hands-on manager with a...
# 1  March 1, 2018  Amazon is driven by being “the world’s most cu...
# 2  March 1, 2018  Amazon is driven by being “the world’s most cu...
# 3  March 1, 2018  Have you ever wondered what it takes to build ...
# 4  March 1, 2018  Have you ever wondered what it takes to build ...
#
#                                 BASIC QUALIFICATIONS  \
# 0  · Proven track record of hiring and managing h...
# 1  · Bachelor’s Degree in Computer Science or rel...
# 2  · Bachelor’s Degree in Computer Science or rel...
# 3  · Bachelors Degree in Computer Science or a re...
# 4  · Bachelors Degree in Computer Science or a re...
#
#                             PREFERRED QUALIFICATIONS
# 0  · Experience building extremely high volume an...
# 1  · Experience building complex software systems...
# 2  · Experience building complex software systems...
# 3  · Masters or PhD in Computer Science· Experien...
# 4  · Masters or PhD in Computer Science· Experien...

# %%
filename= '../../DataSet/Amazon_jobs_dataset - amazon_jobs_dataset.csv'

# %%
with open(filename,encoding='utf-8') as f:
    data = csv.DictReader(f)
    data =list(data)

# %% [markdown]
# # HANDS ON DATA 👐

# %% [markdown]
# ## **Job Location**
#
# **Problem Statement :**
#
# Find number of job openings in Bangalore,IN and in Seattle,US?
#
# Print the Number of Job opening in Bangalore and Seattle as Integer value.
#
# ```
# Output:
#
# CountBangalore CountSeattle
# ```

# %%
# ANSWER HERE
bn = []
se=[]
opening=['Bangalore,IN', 'Seattle,US']
text= 'Bangalore'
text1='Seattle'
count=0

for i in data:
    x= i['location'].find(text)
    y= i['location'].find(text1)
    if x!= -1:
        bn.append(x)
    if y!= -1:
        se.append(x)
            
print(len(bn))
print(len(se))
# Out:
# 66
# 1856

# %% [markdown]
# ## **Job Computer Vision**
#
#
# **Problem Statement :**
#
# What are the total number of job openings related to Computer Vision ?
#
# Note:For finding the job related to computer vision check the Job Title column.
#
# ```
# Output Format
#
# Count
#
# ```

# %%
# ANSWER HERE
cv= 'Computer Vision'
count=0
for i in data:
    if cv in i['Title']:
        print(i['Title'])
        count=count+1
print(count)
# Out:
# Software Development Engineer - Computer Vision
# Software Development Manager - Computer Vision
# Software Development Engineer - Computer Vision
# Senior Software Development Engineer - Computer Vision
# Senior Software Development Engineer - Computer Vision
# Software Development Manager - Computer Vision
# Computer Vision Applied Scientist
# Software Development Engineer - Computer Vision
# Software Development Engineer - Computer Vision
# Principal Computer Vision Scientist
# Software Development Engineer - Computer Vision Frameworks/Acceleration
# Computer Vision and Deep Learning Research Scientist
# Software Development Engineer - Computer Vision
# Software Development Engineer - Computer Vision
# 14

# %%
# 14

# %% [markdown]
# ## **Job Canada**
#
# It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
# Problem Statement :
#
# Find the number of job openings in Canada?
#
# Print the count as the Integer Value
#
# ```
# Output:
#
# Count
# ```

# %%
# ANSWER HERE
count=0
for i in data:
    if i['location'][0:2]=='CA':
        count+=1
print(count)
# Out:
# 156

# %%
# 156

# %% [markdown]
# ## **Job Month 2018**
#
# Problem Statement :
#
# Find the month having most job openings in Year 2018 ?
# Print the month (Month Name i.e January, February, March) and Number of job opening as Integer Value
#
# ```
# Output Format :
#
# MonthName Count
#
# ```

# %%
# ANSWER HERE
x,y,z=0,0,0

for i in data:
    j=int(i['Posting_date'].split(',')[1])
#     print(j)
    k=i['Posting_date'].split(' ')[0]
#     print(k)
    if j==2018:
        if k=='January':
            x+=1
        if k=='February':
            y=y+1
        if k=='March':
            z+=1

print('January',max([x,y,z]))
# Out:
# January 907

# %%
# January   907

# %% [markdown]
# ## **Job Degree**
#
# Problem Statement :
# Find the number of job openings are present if applicant have Bachelor degree?
# Print the count as Integer value
#
# **Note : Here we will use the BASIC QUALIFICATIONS feature to find out whether bachelor degree for Job is required or not. Keywords that can be used are 'Bachelor', 'BS' and 'BA'.**
#
# ```
# Output:
#
# Count
# ```

# %%
# ANSWER HERE
listt= ['Bachelor','BS','BA']
j=set()
for i in range(len(data)):
    d=data[i]['BASIC QUALIFICATIONS']
    for k in listt:
        if k in d:
            j.add(i)
print(len(j))
# Out:
# 2961

# %%
# 2961

# %% [markdown]
# ## **Job Java**
# **Problem Statement :**
#
# Find the country does Amazon need the most number of Java Developer?
# Print the Country(Country Shortcut as given in Dataset) and number of job opening as integer value
#
# ```
# Country NumberofJobs
#
# For example : US 40
# ```

# %%
list1=[]
kword=['Java','java']
for j in range(len(data)):
    city = data[j]['location'].split(',')[0]
    if city not in list1:
        list1.append(city)
print(list1)
# Out:
# ['US', 'IN', 'RO', 'CA', 'DE', 'PL', 'AE', 'ES', 'IT', 'IL', 'UK', 'ZA', 'SG', 'AU', 'IE', 'FR', 'BR', 'CN', 'MX', 'NL', 'JO', 'TW', 'LU', 'JP', '']

# %%
for i in data:
    da=i['DESCRIPTION']
    for l in kword:
# Out:
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java

# %%
# US   2009
